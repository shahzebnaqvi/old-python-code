# %% [markdown]
# # Linear Regression with One Variable

# %%
import os
import tensorflow as tf
import numpy as np
import matplotlib.pyplot as plt

# %%
# Hyper parameters
learning_rate = 1
training_epochs = 1000
display_step = 50

# %% [markdown]
# ## Dataset
#
# Our dataset a wire resistance table from a chip for 20nm process node.
# It is a 2D array of wire-length, wire-width, temperature and wire-resistance.
# We'll use wire length and wire resistance as our dataset for linear regression example.
#
#
# |Wire-length | Wire-width  | Temperature | Resistance
# |------------|-------------|-------------|-------------
# |(meters)    | (meters)    | (degree C)  | (Ohm)
# |3.806e-06   | 1.088e-07   | 79.0494     | 52.897
# |4.307e-06   | 7.517e-08   | 56.2845     | 83.904
# |4.158e-06   | 1.135e-07   | 27.0643     | 52.517
# |5.416e-06   | 8.939e-08   | 42.0784     | 85.435
# |6.274e-06   | 9.090e-08   | 55.5829     | 110.85
# |8.215e-06   | 1.199e-07   | 97.4032     | 119.45
# |6.437e-06   | 6.653e-08   | 75.0783     | 148.11
# |2.823e-06   | 1.028e-07   | 2.48765     | 36.138
# |2.015e-06   | 1.293e-07   | 63.5732     | 22.955
# |6.346e-06   | 6.420e-08   | 77.0031     | 145.52
# |5.008e-06   | 1.047e-07   | 105.656     | 79.024

# %%
#Load dataset
datafile = os.path.join('..','data','res.tbl.gz')
dataset = np.loadtxt(datafile, dtype=np.float32, ndmin=2)
# reduce the dataset for quick experiments
#dataset = dataset[0:100,:]

# %% [markdown]
# ## Normalization
# Since our length values are very small (in microns) and resistance values range from tens to hundreds, it is **very important** normalize the dataset right after loading.

# %%
# normalize the dataset between 0 and 1.
data_min = np.min(dataset, axis=0)
data_max = np.max(dataset, axis=0)

def normalize(d, min, max):
    return (d-min)/(max-min)

def denormalize(d, min, max):
    return ((max-min)*d) + min

dataset = normalize(dataset, data_min, data_max)

# %% [markdown]
# ## Divide the dataset
# into training dataset and validation dataset

# %%
# training dataset percentage is 80%
def divide_dataset(dataset):
    train_pct = 0.8; 
    # divide dataset into training and validation set
    train_index = int(dataset.shape[0]*train_pct)
    t_X = dataset[:train_index,0]
    t_Y = dataset[:train_index,3]
    v_X = dataset[train_index:,0]
    v_Y = dataset[train_index:,3]
    
    return t_X, t_Y, v_X, v_Y

train_X, train_Y, valid_X, valid_Y = divide_dataset(dataset)
n_samples = train_X.shape[0]

# %% [markdown]
# ## Declare Graph Variables
#
# Place to declare plave holders and variables for compute graph

# %%
import tensorflow.compat.v1 as tf

tf.disable_v2_behavior()
# tf Graph Input
X = tf.placeholder("float")
Y = tf.placeholder("float")

# Set model weights
W = tf.Variable(0.5, name="weight")
b = tf.Variable(0.0, name="bias")
# Out:
# WARNING:tensorflow:From C:\Users\Developer\anaconda3\lib\site-packages\tensorflow\python\compat\v2_compat.py:107: disable_resource_variables (from tensorflow.python.ops.variable_scope) is deprecated and will be removed in a future version.
# Instructions for updating:
# non-resource variables are not supported in the long term

# %% [markdown]
# ## Compute Graph
# Construct a linear model

# %%
predicted = W*X + b

# %% [markdown]
# ## Cost function and Optimizer

# %%
# Mean squared error
cost = tf.reduce_sum((predicted-Y)*(predicted-Y))/(2*n_samples)

# Gradient descent
optimizer = tf.train.GradientDescentOptimizer(learning_rate).minimize(cost)

# %% [markdown]
# ## Train the Model

# %%
# Initialize the variables (i.e. assign their default value)
init = tf.global_variables_initializer()

# %%
# Start training
with tf.Session() as sess:
    sess.run(init)

    # Fit all training data
    for epoch in range(training_epochs):
        sess.run(optimizer, feed_dict={X: train_X, Y: train_Y})

        #Display logs per epoch step
        if (epoch+1) % display_step == 0:
            c = sess.run(cost, feed_dict={X: train_X, Y:train_Y})
            print ("Epoch:", '%04d' % (epoch+1), "cost=", "{:.9f}".format(c), \
                "W=", sess.run(W), "b=", sess.run(b))
    
    print( "Optimization Finished!" )

    # Find cost on training and validation dataset.
    training_cost = sess.run(cost, feed_dict={X: train_X, Y: train_Y})
    print ("Training   cost (mean sq. error) =",training_cost)
    validation_cost = sess.run(cost, feed_dict={X: valid_X, Y: valid_Y})
    print ("Validation cost (mean sq. error) =",validation_cost, '\n')
    
    # Record the mode before closing the session
    Weight = sess.run(W)
    Bias   = sess.run(b)
# Out:
# Epoch: 0050 cost= 0.001196220 W= 0.35999772 b= -0.04106047
# Epoch: 0100 cost= 0.001140905 W= 0.31357327 b= -0.018445956
# Epoch: 0150 cost= 0.001128231 W= 0.29135138 b= -0.007621096
# Epoch: 0200 cost= 0.001125327 W= 0.28071448 b= -0.0024395953
# Epoch: 0250 cost= 0.001124662 W= 0.27562284 b= 4.0652303e-05
# Epoch: 0300 cost= 0.001124509 W= 0.27318567 b= 0.0012278634
# Epoch: 0350 cost= 0.001124474 W= 0.27201915 b= 0.0017961089
# Epoch: 0400 cost= 0.001124466 W= 0.27146074 b= 0.0020681336
# Epoch: 0450 cost= 0.001124464 W= 0.27119341 b= 0.002198349
# Epoch: 0500 cost= 0.001124464 W= 0.27106547 b= 0.0022606673
# Epoch: 0550 cost= 0.001124464 W= 0.27100423 b= 0.0022905068
# Epoch: 0600 cost= 0.001124464 W= 0.27097496 b= 0.0023047673
# Epoch: 0650 cost= 0.001124464 W= 0.27096093 b= 0.0023116064
# Epoch: 0700 cost= 0.001124464 W= 0.27095425 b= 0.0023148542
# Epoch: 0750 cost= 0.001124464 W= 0.27095094 b= 0.0023164514
# Epoch: 0800 cost= 0.001124464 W= 0.2709494 b= 0.0023172114
# Epoch: 0850 cost= 0.001124464 W= 0.27094868 b= 0.0023175727
# Epoch: 0900 cost= 0.001124464 W= 0.27094865 b= 0.002317586
# Epoch: 0950 cost= 0.001124464 W= 0.27094865 b= 0.002317586
# Epoch: 1000 cost= 0.001124464 W= 0.27094865 b= 0.002317586
# Optimization Finished!
# Training   cost (mean sq. error) = 0.0011244637
# Validation cost (mean sq. error) = 0.0002610986

# %% [markdown]
# # Denormalize

# %%
# Formulate your trained model as a matrix before denormalization
trained_model = denormalize(train_X * Weight + Bias, data_min[3], data_max[3])

# De normalize dataset
train_X, train_Y, valid_X, valid_Y = divide_dataset(denormalize(dataset, data_min, data_max))

# %% [markdown]
# # Plot Model with Dataset

# %%
#Graphic display
plt.figure(figsize=(8,8))
plt.title('Model and Dataset')
plt.xlabel('Wire length (in microns)')
plt.ylabel('Wire resistance (in Ohms)')
plt.grid()
plt.plot(train_X*1e6, train_Y, 'ro', label='Training data', marker='o', markersize=1)
plt.plot(valid_X*1e6, valid_Y, 'bo', label='Validation data', marker='D', markersize=1)
plt.plot(train_X*1e6, trained_model, label='Training Fitted line')
plt.legend()
plt.show()
# Out:
# C:\Users\DEVELO~1\AppData\Local\Temp/ipykernel_2172/2198471887.py:7: UserWarning: marker is redundantly defined by the 'marker' keyword argument and the fmt string "ro" (-> marker='o'). The keyword argument will take precedence.
#   plt.plot(train_X*1e6, train_Y, 'ro', label='Training data', marker='o', markersize=1)
# C:\Users\DEVELO~1\AppData\Local\Temp/ipykernel_2172/2198471887.py:8: UserWarning: marker is redundantly defined by the 'marker' keyword argument and the fmt string "bo" (-> marker='o'). The keyword argument will take precedence.
#   plt.plot(valid_X*1e6, valid_Y, 'bo', label='Validation data', marker='D', markersize=1)

# %% [markdown]
# # Predict Resistance Values

# %%
def predictResistance(length):
    normalize_length = normalize(length, data_min[0], data_max[0])
    return denormalize(Weight*normalize_length+Bias,data_min[3], data_max[3])

# convert values shows in the table at the top into quads.
res_tbl = [ [3.806e-06, 1.088e-07, 79.0494, 52.897],
            [4.307e-06, 7.517e-08, 56.2845, 83.904],
            [4.158e-06, 1.135e-07, 27.0643, 52.517],
            [5.416e-06, 8.939e-08, 42.0784, 85.435],
            [6.274e-06, 9.090e-08, 55.5829, 110.85],
            [8.215e-06, 1.199e-07, 97.4032, 119.45],
            [6.437e-06, 6.653e-08, 75.0783, 148.11],
            [2.823e-06, 1.028e-07, 2.48765, 36.138],
            [2.015e-06, 1.293e-07, 63.5732, 22.955],
            [6.346e-06, 6.420e-08, 77.0031, 145.52],
            [5.008e-06, 1.047e-07, 105.656, 79.024] ]

for quad in res_tbl:
    predicted_resistance = predictResistance(quad[0])
    print( "Wire length = ", quad[0], ", Predicted Resistance = ", 
          predicted_resistance, ", Actual Resistance =", quad[3],
          ". Diff=", quad[3]-predicted_resistance )
# Out:
# Wire length =  3.806e-06 , Predicted Resistance =  64.35970099943388 , Actual Resistance = 52.897 . Diff= -11.462700999433885
# Wire length =  4.307e-06 , Predicted Resistance =  72.82290900978593 , Actual Resistance = 83.904 . Diff= 11.081090990214065
# Wire length =  4.158e-06 , Predicted Resistance =  70.30590702666726 , Actual Resistance = 52.517 . Diff= -17.788907026667253
# Wire length =  5.416e-06 , Predicted Resistance =  91.55683652172291 , Actual Resistance = 85.435 . Diff= -6.121836521722912
# Wire length =  6.274e-06 , Predicted Resistance =  106.05071371310429 , Actual Resistance = 110.85 . Diff= 4.799286286895708
# Wire length =  8.215e-06 , Predicted Resistance =  138.83931001668378 , Actual Resistance = 119.45 . Diff= -19.38931001668378
# Wire length =  6.437e-06 , Predicted Resistance =  108.80421252685154 , Actual Resistance = 148.11 . Diff= 39.30578747314847
# Wire length =  2.823e-06 , Predicted Resistance =  47.754244963154306 , Actual Resistance = 36.138 . Diff= -11.616244963154308
# Wire length =  2.015e-06 , Predicted Resistance =  34.10499930973224 , Actual Resistance = 22.955 . Diff= -11.149999309732245
# Wire length =  6.346e-06 , Predicted Resistance =  107.26698312776564 , Actual Resistance = 145.52 . Diff= 38.25301687223437
# Wire length =  5.008e-06 , Predicted Resistance =  84.66464317197514 , Actual Resistance = 79.024 . Diff= -5.640643171975142

# %% [markdown]
# # Error Distribution

# %%
def sampleError(sampleData, goldData):
    sampleData = predictResistance(sampleData)
    error = (goldData-sampleData)/goldData
    return error

training_Error   = sampleError(train_X, train_Y)
validation_Error = sampleError(valid_X, valid_Y)

print('Training   error mean=', np.mean(training_Error),   ' and distribution=', np.std(training_Error))
print('Validation error mean=', np.mean(validation_Error), ' and distribution=', np.std(validation_Error))
# Out:
# Training   error mean= -0.053225905  and distribution= 0.22542669
# Validation error mean= -0.050831664  and distribution= 0.22692154

# %% [markdown]
# # Plot Error

# %%
fig = plt.figure(figsize=(20, 10))

plt.subplot(1, 2, 1)
plt.grid()
plt.plot(train_X*1e6, 100*training_Error, 'ro', label='Training Error', marker='o', markersize=1)
plt.title('Training Error')
plt.xlabel('Wire length (in micron)')
plt.ylabel('% ERROR')
plt.legend()


plt.subplot(1, 2, 2)
plt.grid()
plt.plot(valid_X*1e6, 100*validation_Error, 'bo', label='Validation Error', marker='D', markersize=1)
plt.title('Validation Error')
plt.xlabel('Wire length (in micron)')
plt.ylabel('% ERROR')
plt.legend()

plt.show()
# Out:
# C:\Users\DEVELO~1\AppData\Local\Temp/ipykernel_2172/805306656.py:5: UserWarning: marker is redundantly defined by the 'marker' keyword argument and the fmt string "ro" (-> marker='o'). The keyword argument will take precedence.
#   plt.plot(train_X*1e6, 100*training_Error, 'ro', label='Training Error', marker='o', markersize=1)
# C:\Users\DEVELO~1\AppData\Local\Temp/ipykernel_2172/805306656.py:14: UserWarning: marker is redundantly defined by the 'marker' keyword argument and the fmt string "bo" (-> marker='o'). The keyword argument will take precedence.
#   plt.plot(valid_X*1e6, 100*validation_Error, 'bo', label='Validation Error', marker='D', markersize=1)
